# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
pd.set_option('display.max_colwidth', 500)
import time
import requests
import random

# %%
page = requests.get("https://nur-sultan.hh.kz/search/vacancy?area=160&search_field=name&search_field=company_name&search_field=description&text=python&from=suggest_post&hhtmFrom=vacancy_search_list", headers={'User-Agent': 'Custom'})
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="desktop" lang="ru"><!--request: 16537388728284868079192bfd212a40--><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><title class="HH-PageLayout-Title">Работа в Нур-Султане, поиск персонала и публикация вакансий - nur-sultan.hh.kz</title><meta content="summary_large_image" name="twitter:card"/><meta content="nur-sultan.hh.kz — сервис, который помогает найти работу и подобрать персонал в Нур-Султане! Создавайте резюме и откликайтесь на вакансии. Набирайте сотрудников и публикуйте вакансии." name="description"/><meta content="работа, вакансии, работа, поиск вакансий, резюме, работы, работу, работ, ищу работу, поиск" name="keywords"/><meta content="https://i.hh.kz/logos/openGraph/hh.kz.png?v=3" property="og:image"/><meta content="600" property="og:image:width"/><meta content="315" property="og:image:height"/><meta content="Работа в Нур-Султане, поиск персонала и публикация вакансий - nur-sultan.hh.kz" property="og:title"/><meta content="nur-sultan.hh.kz — сервис, который помогает найти работу и подобрать персонал в Нур-Султане! Создавайте резюме и откликайтесь на вакансии. Набирайте сотрудников и публикуйте вакансии." property="og:description"/><script>
#             window.bloko = {
#                 fontUrl: 'https://i.hh.kz/css/other/pages/__fonts_3e2a20dec491e4294c7ec1c4f92c6567.css'
#             };
#             window.globalVars = {
#                 luxEnabled: true,
#                 locale: "ru_RU",
#                 country: "3",
#                 area: "159",
#                 build: "22.21.5.5",
#                 lang: "RU" || "RU",
#                 analyticsParams: "{\"hhtmSource\": \"vacancy_search_list\", \"hhtmFrom\": \"vacancy_search_list\", \"hhtmSourceLabel\": \"\", \"hhtmFromLabel\": \"\", \"screenType\": \"SIMPLE\"}",
#                 requestId: "16537388728284868079192bfd212a40",
#                 pageName: "vacancy_search_list",
#                 sentryDSN: "https://021a400d5c554c00a0b92ac575ff4768@sentry.hh.ru/6",
#                 skillazURL: "https://hh.skillaz.ru",
#                 siteId: "3" || "1",
#                 staticHost: "https://i.hh.kz",
#                 hhcdnHost: "https://hhcdn.ru",
#                 apiHost: "https://api.hh.ru",
#                 timeStamp: "1653738872",
#                 userType: "" || 'anonymous',
#                 cryptedUserId: "",
#                 employerState: "",
#                 login: "",
#                 hhid: "",
#
#
#                 autotestsComponentsInitEnd: false,
#
#                 features: {"is_global_id_enabled_in_gib_fp": null, "chat_write_possibility_controls_enabled": false, "disable_counters": false, "sentry_logging": true, "sentry_request_queue_limit": 20, "fingerprinting_enable": true, "secure_portal_enabled": true, "secure_portal_test_version_enabled": true, "live_reload": false, "employer_extensions_to_detect": "{\"vera\": \"veraBar\", \"friendwork\": \"fwi-popup\", \"potok\": \"potok_io__chrome_extension_iframe\", \"extrasaur\": \"custom-table-iframe-div\", \"cleverStaffLogin\": \"cleverStaffNeedLogin\", \"cleverStaff\": \"cleverStaffBlock\", \"amoCRM\": \"amocrm-scrapper\", \"amoCRM2\": \"js-amo-field-mark-positioned\", \"basecheck\": \"noty_layout__topRight\", \"leo\": \"dataLeo\", \"hrDrive\": \"hh-widget-wrapper\"}", "anonymous_resume_enabled": null, "sentry_js_config": "{\r\n  \"ignorePaths\": {\r\n    \"regexps\": [\r\n      \"[\\\\da-f]+/[\\\\da-f-]+/main\\\\.js\",\r\n      \".*akamaihd\\\\.net.+$\",\r\n      \"\\\\/inj_js\\\\/common\\\\.js\",\r\n      \"fingerprintjs\",\r\n      \"ckeditor4.5\",\r\n      \"[\\\\d\\\\.]+\\\\/combine.js\",\r\n      \"ckeditor/ckeditor\\\\.js\",\r\n      \"axios\\\\/lib\\\\/core\\\\/createError\",\r\n      \"fbevents\\\\.js\",\r\n      \"core-js\\\\/modules\\\\/es\\\\.promise\\\\.js\",\r\n      \"\\\\/ru_RU\\\\/all.js\",\r\n      \"raphael\",\r\n      \"/gpt/pubads_impl\",\r\n      \"Invalid character: '\\\\0'\",\r\n      \"roxot\",\r\n      \"moz-extension:\\\\/\\\\/\",\r\n      \"sovetnik.min.js\"\r\n    ]\r\n  },\r\n  \"ignoreErrors\": {\r\n    \"strings\": [\r\n      \"Loading CSS chunk\",\r\n      \"Cannot read property 'disguiseToken' of undefined\",\r\n      \"Cannot redefine property: googletag\",\r\n      \"InternalError: Promise rejection value is a non-unwrappable cross-compartment wrapper.\",\r\n      \"Failed to update a ServiceWorker: An unknown error occurred when fetching the script.\",\r\n      \"'e.data.indexOf' is not a function\",\r\n      \"Load timeout for modules:\",\r\n      \"__gCrWeb.autofill.extractForms\",\r\n      \"HTML Parsing Error: Unable to modify the parent container element before the child element is closed\",\r\n      \"Uncaught exception: TypeError: Cannot convert 'd.body' to object\",\r\n      \"Node cannot be inserted at the specified point in the hierarchy\",\r\n      \"TypeError: \u041d\u0435\u0434\u043e\u043f\u0443\u0441\u0442\u0438\u043c\u044b\u0439 \u0432\u044b\u0437\u044b\u0432\u0430\u044e\u0449\u0438\u0439 \u043e\u0431\u044a\u0435\u043a\u0442\",\r\n      \"TypeError: Failed to fetch\",\r\n      \"TypeError: Invalid calling object\",\r\n      \"TypeError: 'undefined' is not an object (evaluating 'doc.forms')\",\r\n      \"TypeError: Cannot read property 'precision' of undefined\",\r\n      \"Uncaught exception: TypeError: Cannot convert 'a.mini' to object\",\r\n      \"window.zAdv\",\r\n      \"backbone in Function.e.Router [as extend]\",\r\n      \"this._doc.documentElement\",\r\n      \"Can't find variable: inf\",\r\n      \"SkypeClick2Call\",\r\n      \"\u0421\u0438\u043d\u0442\u0430\u043a\u0441\u0438\u0447\u0435\u0441\u043a\u0430\u044f \u043e\u0448\u0438\u0431\u043a\u0430\",\r\n      \"Invalid or unexpected token\",\r\n      \"Unexpected token <\",\r\n      \"Blocked a frame with origin\",\r\n      \"__show__deepen\",\r\n      \"expected expression, got '<'\",\r\n      \"Cannot read property 'forms' of undefined\",\r\n      \"GM_addStyle is not defined\",\r\n      \"can't redefine non-configurable property \\\"userAgent\\\"\",\r\n      \"Can't find varfiable: auto\",\r\n      \"only one instance of babel-polyfill is allowed\",\r\n      \"this.matches is not a function\",\r\n      \"NS_ERROR_NOT_INITIALIZED\",\r\n      \"NS_ERROR_UNEXPECTED\",\r\n      \"jQuery(...).size is not a function\",\r\n      \"Unexpected token ILLEGAL\",\r\n      \"Unexpected identifier\",\r\n      \"Unexpected end of input\",\r\n      \"yndx_svtn_e\",\r\n      \"Failed to update a ServiceWorker: The script resour ...
#                 variables: {"appEntryPoint": "/webpackBuild/appEntryPoint.d52121e13c0dd110737a.js", "jquery-migrate": "/webpackBuild/jquery-migrate.05988241fc25621da91e.js", "runtime": "/webpackBuild/runtime.6f068656aee2415c5f20.js", "bloko": "/webpackBuild/bloko.b7ec0e13475322a3e7b8.js", "vendors": "/webpackBuild/vendors.163016f164e26b14729b.js", "vendors.lux": "/webpackBuild/vendors.lux.ab6a9663e0af9663c9f2.js", "anonymousUser": "/webpackBuild/anonymousUser.22508265193fa2e8ad28.js"},
#                 cssMaping:
#         {"admin-admin":{"name":"admin","dir":"admin","path":"css/admin/pages/__admin_e503c4b3e66526d8cd1e90562f41359a.css"},"applicant-applicant":{"name":"applicant","dir":"applicant","path":"css/applicant/pages/__applicant_1cfa5ac9ed7f4036c4c0bbc83acce28d.css"},"employer-employer":{"name":"employer","dir":"employer","path":"css/employer/pages/__employer_522a9a81b3179fe9b079197feff438c6.css"},"globals-account":{"name":"account","dir":"globals","path":"css/globals/pages/__account_7570d03c19b071d4c8bcc2882d3ba014.css"},"globals-applicant-services-desktop":{"name":"applicant-services-desktop","dir":"globals","path":"css/globals/pages/__applicant-services-desktop_c28ec38377097405b440d3fa84a5174d.css"},"globals-applicant-services-mobile":{"name":"applicant-services-mobile","dir":"globals","path":"css/globals/pages/__applicant-services-mobile_9563fb82f978251be535f88ed6d97f4d.css"},"globals-bloko-imports":{"name":"bloko-imports","dir":"globals","path":"css/globals/pages/__bloko-imports_789841bd3cc24d4635a59263c097b3ed.css"},"globals-dev-tools":{"name":"dev-tools","dir":"globals","path":"css/globals/pages/__dev-tools_fc08f217009af84bbb61a5230057e476.css"},"globals-error":{"name":"error","dir":"globals","path":"css/globals/pages/__error_d4e16237976f54d6d27d7cd5b1505bce.css"},"globals-globals":{"name":"globals","dir":"globals","path":"css/globals/pages/__globals_f1f5667a55b0a942760480f7c01319cb.css"},"other-chameleon":{"name":"chameleon","dir":"other","path":"css/other/pages/__chameleon_57bd4a0c089457728a8e97ec5b34a39c.css"},"other-ckeditor":{"name":"ckeditor","dir":"other","path":"css/other/pages/__ckeditor_53aa1887f858d0df8bc9aedb9a8bbc1e.css"},"other-fonts":{"name":"fonts","dir":"other","path":"css/other/pages/__fonts_3e2a20dec491e4294c7ec1c4f92c6567.css"},"other-kangaroo":{"name":"kangaroo","dir":"other","path":"css/other/pages/__kangaroo_c5b43af96b687b079dbb52e9c2ab968b.css"},"other-promo":{"name":"promo","dir":"other","path":"css/other/pages/__promo_db24b90c33c74511fee6a2403f0e32a3.css"}}
#     ,
#                 firebaseMessagingSenderId: '805196181446',
#                 firebaseProjectId: 'hh-prod-web',
#                 firebaseApiKey: 'AIzaSyDbhG4QAAPJjUYmVAlGxnP6lznLERG9NUw',
#                 firebaseAppId: '1:805196181446:web:90b284644e2aec29220cc7',
#                 ads_sandbox: '0',
#                 iapsdkTrackingOfferAlias: '46x2pqyuq',
#                 sentryExtraData: {},
#                 microFrontends:
#         {}
#
#             };
#
#             try {
#                 if (typeof window.globalVars.analyticsParams === 'string') {
#                     window.globalVars.analyticsParams = JSON.parse(window.globalVars.analyticsParams)
#                 }
#             } catch(e) {}
#         </script><script>
#             window.globalVars = window.globalVars || {};
#             window.globalVars.bannersBatchUrl = 'https://hhcdn.ru/pv?token=VuKA4jYBLNzNwWKSDXgzPw--&type=unknown&regions=40%2C160&specs=395%2C269%2C397%2C270%2C15%2C272%2C400%2C144%2C273%2C401%2C274%2C277%2C149%2C405%2C279%2C535%2C536%2C24%2C152%2C25%2C538%2C156%2C30%2C161%2C417%2C418%2C420%2C295%2C296%2C172%2C301%2C302%2C303%2C50%2C306%2C183%2C440%2C441%2C443%2C59%2C572%2C446%2C65%2C66%2C196%2C324%2C580%2C327%2C203%2C333%2C334%2C82%2C211%2C89%2C474%2C475%2C221%2C350%2C225%2C358%2C486%2C359%2C231%2C487%2C232%2C744%2C110%2C111%2C623%2C751%2C112%2C113%2C625%2C242%2C116%2C117%2C246%2C256%2C3%2C520%2C9%2C137%2C10&domainAreaId=159&meta=hhuid%3DVuKA4jYBLNzNwWKSDXgzPw--';
#         </script><script class="HHC-Banners-Place-Template" type="text/html"><!--
#             <div class="HHC-Banners-Place HHC-Banner-%id% banner-place banner-place_%id% " data-banner-id="%id%" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class=""></div>
#         --></script><script>
# function ownKeys(e,t){var n=Object.keys(e);if(Object.getOwnPropertySymbols){var o=Object.getOwnPropertySymbols(e);t&&(o=o.filter((function(t){return Object.getOwnPropertyDescriptor(e,t).enumerable}))),n.push.apply(n,o)}return n}function _objectSpread(e){for(var t=1;t<arguments.length;t++){var n=null!=arguments[t]?arguments[t]:{};t%2?ownKeys(Object(n),!0).forEach((function(t){_defineProperty(e,t,n[t])})):Object.getOwnPropertyDescriptors?Object.defineProperties(e,Object.getOwnPropertyDescriptors(n)):ownKeys(Object(n)).forEach((function(t){Object.defineProperty(e,t,Object.getOwnPropertyDescriptor(n,t))}))}return e}function _defineProperty(e,t,n){return t in e?Object.defineProperty(e,t,{value:n,enumerable:!0,configurable:!0,writable:!0}):e[t]=n,e}
# /**
#  * @licence https://www.w3.org/Consortium/Legal/2015/copyright-software-and-document
#  */
# function applyFocusVisiblePolyfill(e){if(!0!==e.focusVisiblePolyfillApplied){e.focusVisiblePolyfillApplied=!0;var t=!1,n=!1,o=null,i={text:!0,search:!0,url:!0,tel:!0,email:!0,password:!0,number:!0,date:!0,month:!0,week:!0,time:!0,datetime:!0,"datetime-local":!0};document.addEventListener("keydown",(function(n){if(!(n.metaKey||n.altKey||n.ctrlKey)){var o=e.activeElement;!r(o)||"INPUT"===o.tagName&&i[o.type]||a(o),t=!0}}),!0),document.addEventListener("mousedown",s,!0),document.addEventListener("pointerdown",s,!0),document.addEventListener("touchstart",s,!0),document.addEventListener("visibilitychange",(function(){"hidden"===document.visibilityState&&(n&&(t=!0),c())}),!0),c(),e.addEventListener("focus",(function(e){r(e.target)&&t&&a(e.target)}),!0),e.addEventListener("blur",(function(e){var t;r(e.target)&&(e.target.classList.contains("focus-visible")||e.target.hasAttribute("data-focus-visible-added"))&&(n=!0,window.clearTimeout(o),o=window.setTimeout((function(){return n=!1}),100),(t=e.target).hasAttribute("data-focus-visible-added")&&(t.classList.remove("focus-visible"),t.removeAttribute("data-focus-visible-added")))}),!0),e.nodeType===Node.DOCUMENT_FRAGMENT_NODE&&e.host?e.host.setAttribute("data-js-focus-visible",""):e.nodeType===Node.DOCUMENT_NODE&&(document.documentElement.classList.add("js-focus-visible"),document.documentElement.setAttribute("data-js-focus-visible",""))}function r(e){return e&&e!==document&&"HTML"!==e.nodeName&&"BODY"!==e.nodeName&&"classList"in e&&"contains"in e.classList}function a(e){e.classList.contains("focus-visible")||(e.classList.add("focus-visible"),e.setAttribute("data-focus-visible-added",""))}function s(){t=!1}function c(){document.addEventListener("mousemove",d),document.addEventListener("mousedown",d),document.addEventListener("mouseup",d),document.addEventListener("pointermove",d),document.addEventListener("pointerdown",d),document.addEventListener("pointerup",d),document.addEventListener("touchmove",d),document.addEventListener("touchstart",d),document.addEventListener("touchend",d)}function d(e){e.target.nodeName&&"html"===e.target.nodeName.toLowerCase()||(t=!1,document.removeEventListener("mousemove",d),document.removeEventListener("mousedown",d),document.removeEventListener("mouseup",d),document.removeEventListener("pointermove",d),document.removeEventListener("pointerdown",d),document.removeEventListener("pointerup",d),document.removeEventListener("touchmove",d),document.removeEventListener("touchstart",d),document.removeEventListener("touchend",d))}}!function(){var e=[];/(ipad|ipod|iphone)/i.test(navigator.userAgent.toLowerCase())&&e.push("ios"),e.length&&(document.getElementsByTagName("html")[0].className+=" ".concat(e.join(" ")))}(),function(){var e={edge:{matches:/edge\/(\d+)/,minVersion:12},firefox:{matches:/firefox\/(\d+)\./,minVersion:40},operaMobile:{matches:/opera\/(\d+).+opera mobi/,minVersion:12},win_safari:{matches:/windows nt.+ version\/(\d+)\.[\d.]+ safari/,minVersion:9},ios_saf:{matches:/cpu(?: iphone)? os (\d+)_[\d_]+ like mac os x/,minVersion:8,exclude:function(e){return-1!==e.indexOf("yabrowser")}},android:{matches:/android (\d+\.\d)/,minVersion:4.1,exclude:function(e){var t=e.match(/webkit\/(\d+(?:\.\d+)?)/)[1];return parseFloat(t)>537}},chrome:{matches:/chrome\/(\d+)\./,minVersion:44},safari:{matches:/macintosh;.+ version\/(\d+)\.[\d.]+ safari/,minVersion:9},opera:{matches:/presto\/.+ version\/(\d+)/,minVersion:999},operaMini:{matches:/opera mini\/(\d+)/,minVersion:999},trident:{matches:/trident\/(\d+)\./,minVersion:999},ie:{matches:/msie (\d+)\./,minVersion:999},ie_mob:{matches:/iemobile\/(\d+)/,minVersion:999}};window.bloko=window.bloko||{},window.bloko.getUserAgentDetails=function(t,n){var o=t.toLowerCase(),i={isSupported:!0,browser:null,version:null},r=function(e,t){return t?Object.keys(e).map((function(n){var o=e[n];return _defineProperty({},n,_objectSpread({},o,{minVersion:t[n]||o.minVersion}))})).reduce((function(e,t){return _objectSpread({},e,{},t)}),{}):e}(e ...
#     </script><meta content="telephone=no" name="format-detection"/><link href="https://i.hh.kz/opensearch-v.xml" rel="search" title="Вакансии hh.ru" type="application/opensearchdescription+xml"/><link href="https://i.hh.kz/opensearch-r.xml" rel="search" title="Резюме hh.ru" type="application/opensearchdescription+xml"/><link href="https://i.hh.kz/apple/hh/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/><link href="https://i.hh.kz/apple/hh/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/><link href="https://i.hh.kz/apple/hh/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="https://i.hh.kz/favicons/310x310.png" name="msapplication-square310x310logo"/><meta content="https://i.hh.kz/favicons/310x150.png" name="msapplication-wide310x150logo"/><meta content="https://i.hh.kz/favicons/150x150.png" name="msapplication-square150x150logo"/><meta content="https://i.hh.kz/favicons/70x70.png" name="msapplication-square70x70logo"/><meta content="https://i.hh.kz/favicons/144x144.png" name="msapplication-TileImage"/><link href="https://i.hh.kz/favicons/hh.ico?v=2015_03_17" rel="icon"/><link href="https://i.hh.kz/css/globals/pages/__bloko-imports_789841bd3cc24d4635a59263c097b3ed.css" rel="stylesheet"/><link href="https://i.hh.kz/css/globals/pages/__globals_f1f5667a55b0a942760480f7c01319cb.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/10137.102110651bc1083db6fd.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/4456.5f01fab62f1846ecae7f.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/41592.03595a13e37200824bf1.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/44765.f547470cc4bc5d866488.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/65900.f06aaef58635502a27cc.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/66536.141c328b49090395303e.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/83640.42e582c13b7ae286b349.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/89131.86290871a77d7756f45e.css" rel="stylesheet"/><link href="https://i.hh.kz/webpackBuild/95030.cf21b539acf8848a8ddd.css" rel="stylesheet"/><!--google-universal-analytics counter-->
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('set', 'allow_ad_personalization_signals', true);
#     gtag('set', 'link_attribution', true);
#             gtag('set', {
#                 'custom_map': {
#                     'dimension1': 'user_type',
#                     'dimension6': 'client_id',
#                                 'dimension7': 'session_id',
#                                 'dimension8': 'browser_id',
#                                 'dimension12': 'vacancies_found',
#                                 'dimension14': 'total_searches',
#                                 'dimension15': 'search_input_type',
#                 }
#             });
#
#         gtag('config', 'UA-11659974-15', {
#             'user_type': 'anonymous',
#             'client_id': gtag('get', 'UA-11659974-15', 'client_id'),
#                     'page_location': 'https://nur-sultan.hh.kz/search/vacancy?area=160&search_field=name&search_field=company_name&search_field=description&text=python&from=suggest_post&hhtmFrom=vacancy_search_list&st=vacancy_simple',
#                     'search_input_type': 'suggest_post',
#                     'vacancies_found': '192',
#                     'total_searches': '1',
#                     'browser_id': 'VuKA4jYBLNzNwWKSDXgzPw--',
#                     'session_id': '615c3a2a943deb156c28a76f2c72d1eb00ed98736f39e20b28060602bb1d4d7f',
#         });
#
# </script>
# <!--/google-universal-analytics counter--><script data-name="HHC/ServiceWorkerRegister" data-params=""></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/appEntryPoint.d52121e13c0dd110737a.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/runtime.6f068656aee2415c5f20.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/bloko.b7ec0e13475322a3e7b8.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/vendors.163016f164e26b14729b.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/vendors.lux.ab6a9663e0af9663c9f2.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/anonymousUser.22508265193fa2e8ad28.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/14208.0b3401909837e7551335.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/26364.d60b7dd730e6fa5e3ad1.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/50462.3584dcbb421a7284a8c1.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/51431.0f85620eecaf01c10bfe.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/53954.5a91e2cea88095235d6c.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/55843.f75aff2305758967b413.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/64875.e33d0720d6373d1d49b4.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/69051.085adae0199a3a27c48a.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/97619.b0099950fc17326e0f77.js"></script><script crossorigin="anonymous" defer="" src="https://i.hh.kz/webpackBuild/VacancySearch.10ec5e134838bd9ac2c5.js"></script><link href="https://nur-sultan.hh.kz/search/vacancy" rel="canonical"/><meta content="True" name="HandheldFriendly"/><meta content="width=device-width, user-scalable=no" name="viewport"/><!--fb-pixel counter-->
# <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '3104992516406988');
#     fbq('track', 'PageView');
#     fbq('trackCustom', 'userType', {user_type: 'anonymous'});
# </script>
# <!--/fb-pixel counter--></head><body class="s-friendly xs-friendly"><script>
#             window.globalVars = window.globalVars || {};
#             window.globalVars.performance = window.globalVars.performance || {};
#             window.globalVars.performance.pageWasActive = document.visibilityState === "visible";
#
#             document.addEventListener("visibilitychange", function(e) {
#                 if (document.visibilityState !== "visible") {
#                     window.globalVars.performance.pageWasActive = false;
#                 }
#             });
#         </script><div class="a11y-fast-nav"><script data-name="HH/A11YLink" data-params='
#                     {
#                         "trls": {
#                             "goToInput": "перейти к поиску",
#                             "goToMainContent": "перейти к основному контенту"
#                         }
#                     }
#                 '></script></div><div class="print-logo-wrapper"><img alt="hh.kz" class="print-logo print-logo_headhunter-com-kz" src="https://i.hh.kz/logos/svg/headhunter.com.kz.svg?v=20052019"/></div><script data-name="HHC/Debug/Grid" data-params=""></script><div class="HHC-Debug-Grid grid-absolute g-hidden"><div class="bloko-columns-wrapper"><div class="bloko-column bloko-column_xs-4 bloko-column_s-8 bloko-column_m-12 bloko-column_l-16 bloko-column_container"><div class="grid__columns-wrapper"><div class="bloko-column bloko-column_xs-1 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-1 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-1 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-1 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-1 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-1 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-0 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-0 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-0 bloko-column_l-1"><div class="grid__column"></div></div><div class="bloko-column bloko-column_xs-0 bloko-column_s-0 bloko-column_m-0 bloko-column_l-1"><div class="grid__column"></div></div></div></div></div></div><div id="HH-React-Error" style="display:none"><div class="bloko-columns-wrapper"><div class="row-content"><div class="bloko-column bloko-column_xs-4 bloko-column_s-8 bloko-column_m-12 bloko-column_l-16">Произошла ошибка. Попробуйте перезагрузить страницу.</div></div></div></div><div id="HH-React-Root"><div><span><!--noindex--></span><noscript><div class="important-notifications--KwjY3GMbm2FeClfZhOKM"><div class="bloko-columns-wrapper"><div class="bloko-v-spacing bloko-v-spacing_base-3"></div><div class="bloko-column bloko-column_xs-4 bloko-column_s-8 bloko-column_m-12 bloko-column_l-16"><div class="site-exceptions-content--So4tdJl6mxPzNDrHNWKJ"><div class="bloko-text">Для работы с нашим сайтом необходимо, чтобы Вы включили JavaScript в вашем браузере.</div></div></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div></div></noscript><span><!--/noindex--></span><div class="supernova-overlay"><div class="supernova-overlay__navi"><div class="bloko-columns-wrapper"><div class="bloko-column bloko-column_xs-0 bloko-column_s-8 bloko-column_m-12 bloko-column_l-16"><div class="supernova-navi supernova-navi_lvl-1"><div class="supernova-navi supernova-navi_lvl-1 supernova-navi_main-content"><div class="supernova-navi"><div class="supernova-navi-item supernova-navi-item_lvl-1 supernova-navi-item_area-switcher HH-Supernova ...
# <script>
#             new Image().src="//counter.yadro.ru/hit;HeadHunter?t14.6;r"+escape(document.referrer)+
#                 ((typeof(screen)=="undefined")?"":";s"+screen.width+"*"+screen.height+"*"+
#                         (screen.colorDepth?screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+";h"+
#                 escape(document.title.substring(0,80))+";"+Math.random()
#         </script>
# <!--/live-internet counter--><!--statad counter-->
# <script>
#       (function(d, w, nav, sc) {
#         function serialize(obj) {
#           return Object.keys(obj)
#             .map(function(key) {
#               return [key, obj[key]].join('=');
#             })
#             .join('&');
#         }
#
#         function getCookie(name) {
#           var matches = d.cookie.match(new RegExp('(?:^|; )' + name.replace(/([\.$?*|{}\(\)\[\]\\\/\+^])/g, '\\$1') + '=([^;]*)'));
#           return matches ? decodeURIComponent(matches[1]) : '';
#         }
#
#         function hit(referrer) {
#           var s = w && w.sessionStorage ? w.sessionStorage : {};
#           var query = {
#             rnd: Math.random().toString(),
#             u: encodeURIComponent(d.URL),
#             r: encodeURIComponent(referrer || d.referrer)
#           };
#
#           try {
#             var e = d.documentElement;
#             query.v = 4;
#             query.sd = 'hh.ru';
#             query.w = w.top === w ? 1 : 0;
#             query.h = d.hidden ? 1 : 0;
#             query.gW = Math.max(e.clientWidth, w.innerWidth || 0);
#             query.gH = Math.max(e.clientHeight, w.innerHeight || 0);
#             query.gDH = Math.max(d.body.scrollHeight, e.scrollHeight, d.body.offsetHeight, e.offsetHeight, d.body.clientHeight, e.clientHeight);
#             query.gDW = Math.max(d.body.scrollWidth, e.scrollWidth, d.body.offsetWidth, e.offsetWidth, d.body.clientWidth, e.clientWidth);
#             query.sW = sc.width || 0;
#             query.sH = sc.height || 0;
#             query.ga = getCookie('_ga');
#             query.dpr = w.devicePixelRatio || '';
#             query.c = (function() {
#               var conn = '';
#               if (nav && nav.connection) {
#                 if (nav.connection.type) conn = nav.connection.type;
#                 else if (nav.connection.effectiveType) conn = 'eff:' + nav.connection.effectiveType;
#               }
#               return conn;
#             })();
#             query.t = s && s._tid ? s._tid : (s._tid = Date.now());
#
#             if (w.performance) {
#               if (w.performance.navigation) {
#                 query.rc = w.performance.navigation.redirectCount;
#                 query.tn = w.performance.navigation.type;
#               }
#
#               if (w.performance.timing) query.dc = (w.performance.timing.secureConnectionStart || w.performance.timing.fetchStart) - w.performance.timing.fetchStart;
#             }
#           } catch (e) {}
#
#           var path = 'https://statad.ru/pixel.gif';
#           var qs = serialize(query);
#           new Image().src = [path, '?', qs].join('');
#         }
#
#         hit();
#
#         var url = w.location.href;
#         var count = 0;
#         var checkInterval = setInterval(function() {
#           if (count >= 50) clearInterval(checkInterval);
#           else if (url !== w.location.href) {
#             hit(url);
#             url = w.location.href;
#             count++;
#           }
#         }, 1000);
#       })(document, window, navigator, screen);
#     </script>
# <!--/statad counter--><!--zero-kz counter-->
# <span id="_zero_3735">
# <noscript>
# <a href="http://zero.kz/?s=3735" target="_blank">
# <img alt="ZERO.kz" height="31" src="//c.zero.kz/z.png?u=3735" width="88"/></a>
# </noscript>
# </span>
# <script type="text/javascript"><!--
#             var _zero_kz_ = _zero_kz_ || [];
#             _zero_kz_.push(["id", 3735]);
#             _zero_kz_.push(["type", 1]);
#
#             (function () {
#                 var a = document.getElementsByTagName("script")[0],
#                         s = document.createElement("script");
#                 s.type = "text/javascript";
#                 s.async = true;
#                 s.src = (document.location.protocol == "https:" ? "https:" : "http:")
#                         + "//c.zero.kz/z.js";
#                 a.parentNode.insertBefore(s, a);
#             })(); //-->
#         </script>
# <!--/zero-kz counter--><!--yandex counter-->
# <script type="text/javascript">
#         (function (d, w, c) {
#             (w[c] = w[c] || []).push(function() {
#                 try {
#                     var initParams = {
#                         id: 2647417,
#                         trackLinks: true,
#                         accurateTrackBounce: true,
#                         clickmap: true,
#                         params: {status: 'anonymous'},
#                         webvisor: true
#                     };
#                     w.yaCounter2647417 = new Ya.Metrika(initParams);
#                     window.yaMetrikaInstance = window.yaMetrikaInstance || w.yaCounter2647417;
#                 } catch(e) { }
#                 if (window.yaMetrikaLoadedCallback instanceof Function) {
#                     window.yaMetrikaLoadedCallback();
#                 }
#             });
#             var n = d.getElementsByTagName("script")[0],
#                 s = d.createElement("script"),
#                 f = function () { n.parentNode.insertBefore(s, n); };
#             s.type = "text/javascript";
#             s.async = true;
#             s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#             if (w.opera == "[object Opera]") {
#                 d.addEventListener("DOMContentLoaded", f, false);
#             } else { f(); }
#         })(document, window, "yandex_metrika_callbacks");
#     </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/2647417" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!--/yandex counter--><!--google-universal-analytics counter-->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-11659974-15"></script>
# <!--/google-universal-analytics counter--><!--vk-targeting counter-->
# <script>
#     window.vkAsyncInit = function() {
#                 window.VK.Retargeting.Init('VK-RTRG-1189007-bw3wY');
#                 window.VK.Retargeting.Hit();
#                 if (window.vkPixelLoadedCallback instanceof Function) {
#                     window.vkPixelLoadedCallback();
#                 };
#         }
#
#     !function() {
#         var t = document.createElement('script');
#         t.type = 'text/javascript';
#         t.async = !0;
#         t.src = 'https://vk.com/js/api/openapi.js?169';
#         document.head.appendChild(t);
#     }();
# </script>
# <noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-1189007-bw3wY" style="position: fixed; left: -999px"/></noscript>
# <!--/vk-targeting counter--><!--mytracker counter-->
# <script>
#     var _tmr = window._tmr || (window._tmr = []);
#
#     function tmrReachGoal(category, event, label) {
#         var goal = '';
#         var goalParams = {};var allowedActions = ['register', 'auth-login-success', 'vacancy-view-contacts'];
#             if (allowedActions.includes(event) || (event === 'resume-create-attempt' && label === 'first')) {
#                 goal = [category, event, label].filter(Boolean).join('_');
#             }if (goal !== '') {
#             _tmr.push({
#                 id: '3209834',
#                 type: 'reachGoal',
#                 goal: goal,
#                 params: goalParams
#             });
#         }
#     }
#     _tmr.push({id: '3209834', type: 'pageView', start: (new Date()).getTime()});
#     (function (d, w, id) {
#         if (d.getElementById(id)) return;
#         var s = d.createElement('script');
#         s.async = true;
#         s.type = 'text/javascript';
#         s.id = id;
#         s.src = 'https://top-fwz1.mail.ru/js/code.js';
#         var x = document.getElementsByTagName('script')[0];
#         x.parentNode.insertBefore(s, x);
#     })(document, window, "topmailru-code");
# </script>
# <noscript>
# <div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3209834;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div>
# </noscript>
# <!--/mytracker counter--><!--/noindex--><script data-name="HH/FloodlightTracker" data-params='
#             {
#                 "loadOnInit": true,
#                 "type": "hh_kz0",
#                 "cat": "all_p0",
#                 "utm_source": "",
#                 "utm_medium": "",
#                 "utm_campaign": "",
#                 "utm_term": ""
#             }
#         '></script></div><script data-name="HH/Vishnu" data-params='
#             {
#                 "employerId": false,
#                 "employerManagerId": false
#             }
#         '></script><div class="Bloko-Notification-Manager notification-manager"><div class="Bloko-React-Notification-Manager"></div></div><noindex><template data-dump-state-length="630432" data-ssr-state-length="492" data-state-length="62" data-xls-state-length="630432" id="HH-Lux-InitialState" style="display:none">{"searchResumeSeoCatalog": {"active": false}, "authPhone": null, "accountTemporarilyLocked": {}, "applicantSignup": {"fields": [], "hideLogin": false}, "applicantVacancyResponseStatuses": {}, "applicantResponseStreaks": {}, "loginTileType": null, "assessments": {"assessments": []}, "resumeViewHistory": {}, "recaptcha": {"isBot": false, "siteKey": null}, "resumeComments": {"status": "FETCH"}, "userId": null, "userSearchPointsByResumeHash": {}, "commentsByUserId": {}, "applicantPackageType": "basic", "applicantServiceType": "", "applicantPaymentBackUrl": "", "applicantAnalyticsAction": "", "applicantPaymentTypes": [], "applicantAvailableResumeServices": [], "applicantPackageContent": [], "applicantAvailableQuantities": [], "applicantServicesPrices": {}, "applicantPaymentSource": "desktop", "applicantFindJobRecommendedQuantity": null, "relatedVacancies": {"vacancies": []}, "vacancyAnalyticsConversion": null, "employerMarketSegmentType": null, "vacancyMessages": [], "vacancyFeedback": {}, "relocationWarning": {}, "vacancyResponsePopup": {}, "vacancyConstructor": {"vacancyBrandedTemplates": [], "expirationTime": null}, "vacancyConstructorBackOfficeView": null, "vacancyConstructorTemplateMode": null, "vacancyConstructorMobilePreview": {"templateId": null}, "vacancyConstructorSettings": null, "printVersion": {}, "negotiationsHistory": [], "surveys": [], "employerManagerId": null, "employerAdvice": null, "employerAdvices": [], "employerNoAdviceArticles": [], "anonymousUserType": null, "employerStatus": {"category": "", "state": "", "countryId": "", "suspiciousState": "NOT_SUSPICIOUS"}, "fetchingData": false, "activeResumeAccessType": null, "resumeVisibilityEmployerWhitelist": {"items": [], "total": 0, "page": 0, "perPage": 10, "isFetching": false}, "resumeVisibilityEmployerBlacklist": {"items": [], "total": 0, "page": 0, "perPage": 10, "isFetching": false}, "resumeVisibilityEmployerSearchResultsWhitelist": {"items": [], "total": 0}, "resumeVisibilityEmployerSearchResultsBlacklist": {"items": [], "total": 0, "isFetching": false}, "resumeExportTypes": [], "resumeLanguages": [], "resumeShareButtons": null, "resumeViewBackoffice": {}, "accountHistoryServices": {}, "accountHistoryReplenishments": {}, "accountHistoryExpenditures": {}, "applicantResumes": [], "allowedSMSCountries": null, "applicantSuitableVacancyByResume": {}, "resumeIdsProfTestAttached": [], "resumeFormAttributes": {"status": ""}, "resumeFormConditions": {}, "resumeFormDefaults": {}, "resumeFormFields": {"title": [{"string": ""}]}, "resumeFormModerationNotes": [], "suggestedKeySkills": [], "artifactRules": {}, "resumeFormLanguages": [], "resumeFormVacancy": null, "educationLevels": [], "employments": [], "schedules": [], "driverLicenseTypes": [], "vacancyClickmeLanding": {}, "employerExperiences": {}, "chatWritePossibilities": [], "employerEmployments": {}, "employerWorkSchedules": {}, "employerLicenses": {}, "partTimeTypes": {}, "employerConstructor": {"editMode": false, "previewModeWithBranding": true, "version": null, "canEdit": false, "modalError": null, "widgets": [], "widgetsOrder": [], "saveStatus": "DIRTY", "hasUnsavedChanges": false, "pictureId": null, "resizeStatus": "DIRTY", "images": [], "tabPrices": [], "hasConstructor": false, "hasService": false, "readyToActivateCartId": null}, "employerConstructorSettings": {"pictureSettings": {}}, "employerConstructorAutoAddWidget": null, "employerLogo": {"logoUrl": null, "logoStatus": "DIRTY"}, "employerSeoCities": [], "employerPageIsViewMode": null, "employerButtons": {}, "employerInsiderInterview": {}, "managerActiveCount": {}, "managerNegotiationStats": {}, "vacanciesByManager": {}, "vacancyCardInfo": {}, "su ...
#             if (window.performance && window.performance.mark) {
#                 window.performance.mark('fmp_body');
#             }
#         </script></body></html>

# %%
soup.find_all(class_='vacancy-serp-item')
# Out:
# [<div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66137933?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Backend developer (Python)</a></span></span><span class="bloko-icon bloko-icon_torch bloko-icon_initial-tertiary"></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">от <!-- -->300 000<!-- --> <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text bloko-text_tertiary" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/4702394?hhtmFrom=vacancy_search_list">ТОО <!-- -->Click Logistics</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="vacancy-serp-item-control-xs-only"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии Click Logistics" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/4702394?hhtmFrom=vacancy_search_list"><img alt="Click Logistics" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/3429246.png"/></a></div></div></div></div><div class="vacancy-serp-item-control-gt-xs"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии Click Logistics" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/4702394?hhtmFrom=vacancy_search_list"><img alt="Click Logistics" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/3429246.png"/></a></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Option pool.</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Коммерческий опыт программирования на Python от 2 лет. Знакомство Machine Learning будет плюсом. С# и знакомство с Unity будет большим...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66137933&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55862777?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Junior Back-end/Go Developer</a></span></span><span class="bloko-icon bloko-icon_torch bloko-icon_initial-tertiary"></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/1150337?hhtmFrom=vacancy_search_list">ТОО <!-- -->LEOPART CENTER</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="vacancy-serp-item-control-xs-only"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии LEOPART CENTER" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/1150337?hhtmFrom=vacancy_search_list"><img alt="LEOPART CENTER" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/4112061.png"/></a></div></div></div></div><div class="vacancy-serp-item-control-gt-xs"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии LEOPART CENTER" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/1150337?hhtmFrom=vacancy_search_list"><img alt="LEOPART CENTER" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/4112061.png"/></a></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка новых продуктов, используя микросервисный подход (охват более 2 тыс b2b клиентов). Использование различных инструментов разработки: SQL/NoSQL...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Знание одного и/или нескольких backend языков (Golang(приоритетный), C/C, PHP, Python, C#, Java). Знание Git. Опыт работы с...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55862777&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55896542?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Backend Jun+ / Middle разработчик (Python/Node.js)</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">300 000 – 800 000 <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/5727675?hhtmFrom=vacancy_search_list">ТОО <!-- -->GLOBAL Innotion</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Участие в разработке веб-приложений. Разработка архитектуры баз данных. Разрабатывать и развивать бэкенд платформ Компании и мобильных приложений (новые фичи...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы с технологиями контейнеризации приложений: Docker/Kubernetes. Знание Rest API. Знание Nginx. Python Flask / Node.js. Знание PostgreSql. </div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55896542&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66075600?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Python developer</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/818393?hhtmFrom=vacancy_search_list">Chocofamily</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div><div class="vacancy-serp-item__meta-info-link"><a data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winners" href="http://kz.hrbrand.ru/" rel="nofollow noindex"><span class="vacancy-serp-bage-hr-brand"></span></a></div><div class="vacancy-serp-item__meta-info-link"></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Работа с Rest API для интеграции с другими системами (внешние, внутренние). Плотная работа с данными в SQL через django-orm...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Требования к знаниям и навыкам: Уверенный опыт работы с Django, FastAPI, DRF, Django-ORM, Git, Swagger или PostmanCollection, Celery, Redis. </div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66075600&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66119584?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">QA Manual инженер / стажер</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/5991214?hhtmFrom=vacancy_search_list">ЧК ITS PARTNER LTD.</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Проект Arlo представляет собой систему домашнего видеонаблюдения, эволюционирующую в полноценную систему Smart Home, стартовал шесть лет назад и находится на...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">При успешном прохождении стажировки, стажер уже имеет работу и знания по проекту и технологиям. Практика англ.яз. Опыт в проекте, ориентированном...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66119584&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66137068?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Аналитик (Data Analyst)</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/146547?hhtmFrom=vacancy_search_list">АО <!-- -->Jusan Bank</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="vacancy-serp-item-control-xs-only"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии Jusan Bank" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/146547?hhtmFrom=vacancy_search_list"><img alt="Jusan Bank" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/3899280.png"/></a></div></div></div></div><div class="vacancy-serp-item-control-gt-xs"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии Jusan Bank" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/146547?hhtmFrom=vacancy_search_list"><img alt="Jusan Bank" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/3899280.png"/></a></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">...в Python или иных технологий. Очищать и подготавливать выгруженные данные для дальнейшей аналитики. Анализировать данные при помощи Excel, Python или...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Высшее образование. От 2-х лет в аналитике данных. Обязательно - SQL, Excel , желательно - MS Power BI, SAP BI, Python.</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item-activity" data-qa="vacancy-serp-item-activity">Работодатель сейчас онлайн</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66137068&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66135784?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Python/Django Web Developer (Remote)</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">4 000 – 6 000 <!-- -->USD</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text bloko-text_tertiary" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/1738507?hhtmFrom=vacancy_search_list">Soshace</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div><div class="vacancy-serp-item__label" data-qa="vacancy-label-item-first"><div class="search-result-label search-result-label_few-responses" data-qa="vacancy-label-be-first"><div class="bloko-text">Будьте первыми</div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">TrCr* is a platform-as-a-service provider that enables fintechs to build next-generation banking and investment products. </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Experience with RabbitMQ, Kafka, ElasticSearch, data streamingReady and want to work with multiple technologies. Experience with Python Django and Django...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66135784&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55487180?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Senior DevOps in Blockchain Startup</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">315 000 – 860 000 <!-- -->руб.</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/5973965?hhtmFrom=vacancy_search_list">Петухова Алия</a></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка и тех. обслуживание за счет внедрения инструментов, которые автоматизируют работу и улучшат процесс разработки. Автоматизация delivery-процессов и capacity...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы с крупномасштабными распределенными средами. Опыт разработки с помощью Go, Python или других языков. Опыт работы с Docker, Kubernetes...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55487180&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55546883?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Data Analyst (Middle/Senior)</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/2524797?hhtmFrom=vacancy_search_list">inDriver</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Сбор, анализ и обработка внутренних данных. Составление и подготовка статистической отчетности по запросам от отделов. Аналитика и прогнозы. </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Базовые знания теории вероятностей, математической статистики, линейной алгебры. Знания Python, SQL. Знания основных продуктовых метрик (LTV, ARPU, Retention и т...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55546883&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66095960?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Senior Python Developer</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/737295?hhtmFrom=vacancy_search_list">ТОО <!-- -->Prime Source</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div><div class="vacancy-serp-item__label" data-qa="vacancy-label-item-first"><div class="search-result-label search-result-label_few-responses" data-qa="vacancy-label-be-first"><div class="bloko-text">Будьте первыми</div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Посещение регулярных встреч для обсуждения текущей работы и будущих целей наших проектов.</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">В связи с активным ростом и развитием, открыта позиция Senior Python разработчика в зарубежный проект, который способен брать ответственность за...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66095960&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/53238714?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Data Analyst - Metasearch</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text bloko-text_tertiary" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/4447568?hhtmFrom=vacancy_search_list">KIVORK</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Анализировать данные и составлять отчеты. Преобразовывать большие массивы данных в инсайты посредством дэшбордов. Проводить углубленный анализ в метапоиске для понимания...</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Ответственность и инициативность. Коммуникативные навыки, умение работать в команде. Опыт с Google Analytics, Google Tag Manager. Знание Python. Знание SQL.</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=53238714&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/51200595?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Разработчик</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/78220?hhtmFrom=vacancy_search_list">Евразийский банк, АО</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div><div class="vacancy-serp-item__meta-info-link"><a data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winners" href="http://kz.hrbrand.ru/" rel="nofollow noindex"><span class="vacancy-serp-bage-hr-brand"></span></a></div><div class="vacancy-serp-item__meta-info-link"></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="vacancy-serp-item-control-xs-only"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии Евразийский банк, АО" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/78220?hhtmFrom=vacancy_search_list"><img alt="Евразийский банк, АО" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/467008.jpeg"/></a></div></div></div></div><div class="vacancy-serp-item-control-gt-xs"><div class="vacancy-serp-item-body__logo"><a aria-label="Вакансии Евразийский банк, АО" data-qa="vacancy-serp__vacancy-employer-logo" href="/employer/78220?hhtmFrom=vacancy_search_list"><img alt="Евразийский банк, АО" class="vacancy-serp-item-logo" loading="lazy" src="https://hhcdn.ru/employer-logo/467008.jpeg"/></a></div></div></div><div><div class="vacancy-serp-item__label" data-qa="vacancy-label-item-first"><div class="search-result-label search-result-label_few-responses" data-qa="vacancy-label-be-first"><div class="bloko-text">Будьте первыми</div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка голосовых роботов на базе искусственного интеллекта. Поддержка работы голосовых роботов. Формирование отчетности по результатам обзвона голосовыми роботами. </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт в разработке на любом языке программирования. Базовый уровень Python / Java. Знание MS SQL. Уровень английского - средний и выше. </div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=51200 ...
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/66122262?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Middle Data Engineer/Команда Подготовки онлайн данных</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/25880?hhtmFrom=vacancy_search_list">Kaspi Bank, АО</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div><div class="vacancy-serp-item__label" data-qa="vacancy-label-item-first"><div class="search-result-label search-result-label_few-responses" data-qa="vacancy-label-be-first"><div class="bloko-text">Будьте первыми</div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Подготовка удобных для использования онлайн событий для систем принятия решений. - Оптимизация процессов по генерации событий.</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Требуемый опыт работы: 1–3 года. - Хорошее владение Python 3.6. - Опыт работы с библиотеками: datetime, os, configparser, cx_Oracle, confluent_kafka...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=66122262&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/54452797?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Data-инженер</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/40662?hhtmFrom=vacancy_search_list">Kolesa Group</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div><div class="vacancy-serp-item__meta-info-link"><a data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winners" href="http://kz.hrbrand.ru/" rel="nofollow noindex"><span class="vacancy-serp-bage-hr-brand"></span></a></div><div class="vacancy-serp-item__meta-info-link"></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Анализ первоисточников (MySql, MongoDb, ElasticSearch, API). Разрабатывать и поддерживать ELT/ETL-процессы (Python, SQL, Airflow). Оптимизация запросов (SQL). </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы с базами данных. Хороший уровень знания языка запросов SQL и Python. Понимание как устроена Хранилища данных и объектно...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=54452797&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/50464787?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">MLOps Backend-разработчик</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">800 000 – 1 200 000 <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/40662?hhtmFrom=vacancy_search_list">Kolesa Group</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div><div class="vacancy-serp-item__meta-info-link"><a data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winners" href="http://kz.hrbrand.ru/" rel="nofollow noindex"><span class="vacancy-serp-bage-hr-brand"></span></a></div><div class="vacancy-serp-item__meta-info-link"></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div><div class="vacancy-serp-item__label" data-qa="vacancy-label-item-first"><div class="search-result-label search-result-label_few-responses" data-qa="vacancy-label-be-first"><div class="bloko-text">Будьте первыми</div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Обеспечивать мониторинг и отказоустойчивую работу сервисов. Поддерживать и рефакторить инфраструктуру на Python (FastAPI, Tornado). Писать и поддерживать автотесты. </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Уверенное знание хотя бы одного языка программирования (Python, PHP, Go, C#, Java или другого). Опыт работы с бэкендом и инфраструктурой...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=50464787&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/52122811?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Data аналитик/Риск-менеджер</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/123401?hhtmFrom=vacancy_search_list">АО <!-- -->Банк ЦентрКредит</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div><div class="vacancy-serp-item__meta-info-link"><a data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winners" href="http://kz.hrbrand.ru/" rel="nofollow noindex"><span class="vacancy-serp-bage-hr-brand"></span></a></div><div class="vacancy-serp-item__meta-info-link"></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы</div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Бизнес аналитика при внедрении проектов. Поиск, анализ и внедрение инструментов противодействия мошенничеству в розничном кредитовании. Работа с данными. </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">...математики, IT сфера, финансы. Желателен опыт работы в банковской сфере не менее 2-х лет. Знание SQL, Python, продуктов SAS.</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=52122811&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55491809?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Программист по обеспечению качества ПО</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">300 000 – 550 000 <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/6105020?hhtmFrom=vacancy_search_list">ТОО <!-- -->Suretter Software (Суреттер Софтваре)</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы<!-- -->, <span class="metro-station"><span class="metro-point" style="color:#CD0505"></span>Байконур</span></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Выполнение ручных (manual) и автоматических (automated) тестов. Анализ, регистрация и описание полученных результатов. Коммуникация с заинтересованными лицами (внутренняя/внешняя). </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Знание и базовый опыт программирования на C/C, Java, Python и т.п.. Знание английского языка (в основном – хорошее умение...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55491809&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55452041?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Tech Lead Python разработки</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">от <!-- -->1 000 000<!-- --> <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/5676019?hhtmFrom=vacancy_search_list">ТОО <!-- -->MyCar Group</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы<!-- -->, <span class="metro-station"><span class="metro-point" style="color:#CD0505"></span>Алатау</span></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Выстраивать процессы разработки. Наим сотрудников. Разработка плана развития тех. направления. Обеспечение стабильной работы системы. Контроль качества. Внутреннее тех. развитие сотрудников. </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы с микросервисной архитектурой/монолитной системой. Сильный background python. Опыт работы с Django/DRF/FastAPI. Опыт работы с Celery...</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55452041&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/53790315?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Senior Backend-разработчик</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">до <!-- -->1 500 000<!-- --> <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/2336755?hhtmFrom=vacancy_search_list">ТОО <!-- -->Relog.kz</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы<!-- -->, <span class="metro-station"><span class="metro-point" style="color:#CD0505"></span>Абая</span></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div><div class="vacancy-serp-item__label" data-qa="vacancy-label-item-first"><div class="search-result-label search-result-label_few-responses" data-qa="vacancy-label-be-first"><div class="bloko-text">Будьте первыми</div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-2"></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Писать сервер на javascript, Meteor, NodeJS, Go (но язык для нас не самое главное, главное - какой ты инженер). </div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы над высоконагруженными проектами. Желание разрабатывать ядро продукта. Знание других языков программирования GO/Python.</div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=53790315&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>,
#  <div class="vacancy-serp-item" data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_standard_plus"><div class="vacancy-serp-item__layout"><div class="vacancy-serp-item-body"><div class="vacancy-serp-item-body__main-info"><div class=""><h3 class="bloko-header-section-3" data-qa="bloko-header-3"><span class="resume-search-item__name"><span class="g-user-content" data-page-analytics-experiment-event="vacancy_search_suitable_item"><a class="bloko-link" data-qa="vacancy-serp__vacancy-title" href="https://nur-sultan.hh.kz/vacancy/55524268?from=vacancy_search_list&amp;hhtmFrom=vacancy_search_list&amp;query=python" target="_blank">Преподаватель языков программирования</a></span></span></h3><div class="bloko-v-spacing bloko-v-spacing_base-1"></div><span class="bloko-header-section-3" data-qa="vacancy-serp__vacancy-compensation">до <!-- -->400 000<!-- --> <!-- -->KZT</span><div class="bloko-v-spacing bloko-v-spacing_base-3"></div></div><div class="vacancy-serp-item-company"><div class="vacancy-serp-item__info"><div class="bloko-text"><div class="vacancy-serp-item__meta-info-company"><a class="bloko-link bloko-link_kind-tertiary" data-qa="vacancy-serp__vacancy-employer" href="/employer/6116334?hhtmFrom=vacancy_search_list">ТОО <!-- -->2дэй академи</a></div><div class="vacancy-serp-item__meta-info-badges"><div class="vacancy-serp-item__meta-info-link"><a class="bloko-link" href="https://feedback.hh.ru/article/details/id/5951" target="_blank"><span class="vacancy-serp-bage-trusted-employer"></span></a></div></div></div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy-address">Алматы<!-- -->, <span class="metro-station"><span class="metro-point" style="color:#CD0505"></span>Москва</span></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div></div></div></div><div class="vacancy-serp-item__info"><div class="g-user-content"><div class="bloko-text" data-qa="vacancy-serp__vacancy_snippet_responsibility">Подготовка методического материала по выбранному языку программирования. Обучение программированию. Контроль успеваемости и выполнения заданий. Предоставление обратной связи ученикам.</div><div class="bloko-text bloko-text_no-top-indent" data-qa="vacancy-serp__vacancy_snippet_requirement">Знание теории Алгоритмов и структуры данных. Знание синтаксиса языка программирования. Знание архитектуры приложений. Понимание жизненного цикла разработки программного обеспечения. </div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div></div><div class="bloko-v-spacing bloko-v-spacing_base-4"></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="vacancy-serp-item-controls"><div class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_response"><a class="bloko-button bloko-button_kind-primary bloko-button_scale-small" data-qa="vacancy-serp__vacancy_response" href="/applicant/vacancy_response?vacancyId=55524268&amp;hhtmFrom=vacancy_search_list"><span>Откликнуться</span></a></div></div></div></div></div>]

# %%
name = [i.text for i in soup.find_all(class_='resume-search-item__name')]
name
# Out:
# ['Backend developer (Python)',
#  'Junior Back-end/Go Developer',
#  'Backend Jun+ / Middle разработчик (Python/Node.js)',
#  'Python developer',
#  'QA Manual инженер / стажер',
#  'Аналитик (Data Analyst)',
#  'Python/Django Web Developer (Remote)',
#  'Senior DevOps in Blockchain Startup',
#  'Data Analyst (Middle/Senior)',
#  'Senior Python Developer',
#  'Data Analyst - Metasearch',
#  'Разработчик',
#  'Middle Data Engineer/Команда Подготовки онлайн данных',
#  'Data-инженер',
#  'MLOps Backend-разработчик',
#  'Data аналитик/Риск-менеджер',
#  'Программист по обеспечению качества ПО',
#  'Tech Lead Python разработки',
#  'Senior Backend-разработчик',
#  'Преподаватель языков программирования']

# %%
len(name)
# Out:
# 20

# %%
link =[i.find('a').get('href') for i in soup.find_all(class_='resume-search-item__name')]
link
# Out:
# ['https://nur-sultan.hh.kz/vacancy/66137933?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55862777?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55896542?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/66075600?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/66119584?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/66137068?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/66135784?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55487180?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55546883?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/66095960?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/53238714?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/51200595?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/66122262?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/54452797?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/50464787?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/52122811?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55491809?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55452041?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/53790315?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python',
#  'https://nur-sultan.hh.kz/vacancy/55524268?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=python']

# %%
len(link)
# Out:
# 20

# %%
employer = [i.text for i in soup.find_all(class_='vacancy-serp-item__meta-info-company')]
employer
# Out:
# ['ТОО\xa0Click Logistics',
#  'ТОО\xa0LEOPART CENTER',
#  'ТОО\xa0GLOBAL Innotion',
#  'Chocofamily',
#  'ЧК ITS PARTNER LTD.',
#  'АО\xa0Jusan Bank',
#  'Soshace',
#  'Петухова Алия',
#  'inDriver',
#  'ТОО\xa0Prime Source',
#  'KIVORK',
#  'Евразийский банк, АО',
#  'Kaspi Bank, АО',
#  'Kolesa Group',
#  'Kolesa Group',
#  'АО\xa0Банк ЦентрКредит',
#  'ТОО\xa0Suretter Software (Суреттер Софтваре)',
#  'ТОО\xa0MyCar Group',
#  'ТОО\xa0Relog.kz',
#  'ТОО\xa02дэй академи']

# %%
description=[]
for url in link:
    page = requests.get(url,headers={'User-Agent': 'Custom'})
    # Getting the webpage's content in pure html
    soup = bs(page.content)
    description.append(",".join([i.text for i in soup.find_all(class_='vacancy-description')]))

# %%
# Creating a DataFrame to store our newly scraped information
df = pd.DataFrame()
# Storing the quotes and authors in their respective columns
df['Name of the job'] = name
df['Description'] = description
df['Employer'] = employer

# %%
df
# Out:
#                                           Name of the job  \
# 0                              Backend developer (Python)
# 1                            Junior Back-end/Go Developer
# 2      Backend Jun+ / Middle разработчик (Python/Node.js)
# 3                                        Python developer
# 4                              QA Manual инженер / стажер
# 5                                 Аналитик (Data Analyst)
# 6                    Python/Django Web Developer (Remote)
# 7                     Senior DevOps in Blockchain Startup
# 8                            Data Analyst (Middle/Senior)
# 9                                 Senior Python Developer
# 10                              Data Analyst - Metasearch
# 11                                            Разработчик
# 12  Middle Data Engineer/Команда Подготовки онлайн данных
# 13                                           Data-инженер
# 14                              MLOps Backend-разработчик
# 15                            Data аналитик/Риск-менеджер
# 16                 Программист по обеспечению качества ПО
# 17                            Tech Lead Python разработки
# 18                             Senior Backend-разработчик
# 19                  Преподаватель языков программирования
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Description  \
# 0   Требуемый опыт работы: 1–3 годаПолная занятость, удаленная работаМы применяем механики знаменитой игры "Тетрис" в такой консервативной индустрии как - Логистика. Наши клиенты - крупные европейские транспортные компании.ClickLog - это небольшая, но действительно дружная команда. Среди наших клиентов крупные европейские логистические операторы, производители и даже аэропорт.Мы растем, наш продукт развивается, поэтому мы ищем тебя, если ты имеешь:  Коммерческий опыт программирования на Python о...
# 1   Требуемый опыт работы: 1–3 годаПолная занятость, полный деньУникальная возможность быть в команде профессионалов и расти по четко выстроенной системе грейдовteam.auto: создаем решения для рынка Казахстана и ЕвропыИщем Junior Go разработчика в продвинутую IT команду AUTO.KZ Ожидаем от тебя ‍Опыт разработки от 6 месУверенное знание основ программированияЗнание одного и/или нескольких backend языков (Golang(приоритетный), C/C++, PHP, Python, C#, Java)Знание GitОпыт работы с SQLЖелание и способн...
# 2   Требуемый опыт работы: 1–3 годаПолная занятость, полный деньОбязанности:  Участие в разработке веб-приложений разработка архитектуры баз данных; разрабатывать и развивать бэкенд платформ Компании и мобильных приложений (новые фичи, доработка текущих, работа над улучшением кодовой базы);  Требования:  знание ООП  опыт разработки микросервисов как большой плюс;   опыт работы с реляционными базами данных;   опыт работы с технологиями контейнеризации приложений: Docker/Kubernetes;  знание Rest A...
# 3   Требуемый опыт работы: 1–3 годаПолная занятость, полный деньДорогие соискатели, у нас срочная вакансия в департаменте Финансов! Нужно будет заниматься разработкой для автоматизации работы финансового и бухгалтерского департаментов. Классно, если вам нравится находить решения, которые упрощают операционку и делают удобными ежедневные процессы.  Требования к знаниям и навыкам:  Уверенный опыт работы с Django, FastAPI, DRF, Django-ORM, Git, Swagger или PostmanCollection, Celery, Redis; Опыт раб...
# 4   Требуемый опыт работы: не требуетсяСтажировка, полный деньО проекте: Проект Arlo представляет собой систему домашнего видеонаблюдения, эволюционирующую в полноценную систему Smart Home, стартовал шесть лет назад и находится на стадии активного развития. Менеджмент в Калифорнии. Веб-приложение предлагает широкий набор функций: добавление и настройка устройств, настройка режимов и автоматизированных механизмов их смены по расписанию, стриминг live video и просмотр записанных клипов с камер вид...
# 5   Требуемый опыт работы: 1–3 годаПолная занятость, полный день\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t@import url("https://fonts.googleapis.com/css?family=Ubuntu:400,700");\n\n\t@keyframes fade {\n\t\t0%, 100% {\n\t\t\topacity: 0;\n\t\t}\n\n\t\t50% {\n\t\t\topacity: 1;\n\t\t}\n\t}\n\n\t@keyframes bounce {\n\t\t0% {\n\t\t\ttransform: translateY(0) translateX(0);\n\t\t}\n\n\t\t100% {\n\t\t\ttransform: translateY(-20%) translateX(-20%);\n\t\t}\n\t}\n\n\t@keyframes path {\n\t\t0% {\n\t\t\ttransform: trans...
# 6   Требуемый опыт работы: 3–6 летПолная занятость, удаленная работаSoshace is recruitment company, we help talents to find a remote job or with ability for relocation. Currently we are looking for Python developer for TrCr* company.About TrCr* company​​​​​​​TrCr* is a platform-as-a-service provider that enables fintechs to build next-generation banking and investment products. By providing as-a-service access to the technology, as well as the complex infrastructure of compliance, regulation, pa...
# 7   Требуемый опыт работы: 3–6 летПолная занятость, полный деньО компании: Nihongo Online School - компания, основанная в 2019 году с целью помощи иностранцам, работающим в японских компаниях. Основные сферы деятельность компании - обучение японскому языку, коучинг, аутстаффинг.Мы будем очень благодарны, если при отклике вы приложите версию вашего резюме на английском языке.   Обязанности:   Разработка и тех. обслуживание за счет внедрения инструментов, которые автоматизируют работу и улучшат пр...
# 8   Требуемый опыт работы: 1–3 годаПолная занятость, полный деньinDriver — международный сервис пассажирских перевозок. Мы создаем глобальный высокотехнологичный продукт, который меняет жизнь миллионов людей к лучшему. Входим в топ-3 мобильных сервисов для заказа поездок в мире — 100 млн. установок, 1 млрд. сделок, 600+ городов в 42 странах мира. Какие задачи предстоит решать:  сбор, анализ и обработка внутренних данных; составление и подготовка статистической отчетности по запросам от отделов; ...
# 9   Требуемый опыт работы: 1–3 годаПолная занятость, полный деньPrime Source — это мощный центр разработки программного обеспечения, внедрения технологичных решений, управленческого и ИТ-консалтинга. В течение десятилетия мы завершили свыше 300 проектов в крупнейших организациях Казахстана, России и Соединённых Штатов. В связи с активным ростом и развитием, открыта позиция Senior Python разработчика в зарубежный проект, который способен брать ответственность за команду и проект, силен не только ...
# 10  Требуемый опыт работы: 1–3 годаПолная занятость, удаленная работаВозможно временное оформление: договор услуг, подряда, ГПХ, самозанятые, ИПKivork - это международная IT компания, специализирующиеся в разработке собственных информационно-технологических решений. Мы создаем и управляем проектами, хорошо известными на американском рынке, такими как: Wow Fare, Ovago, HOP2 и Arangrant. Компания Kivork располагает штатом более, чем в 750 человек и представительствами в разных странах, таких как М...
# 11  Требуемый опыт работы: 1–3 годаПолная занятость, полный день\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t@import url("https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600");\n\n\t.tmpl-hh__wrapper {\n\t\tfont-family: "Montserrat", sans-serif;\n\t\tcolor: #fff;\n\t\tfont-weight: 400;\n\t\tfont-size: 15px;\n\t\tline-height: 1.5;\n\t\tposition: relative;\n\t\toverflow: hidden;\n\t\tmargin: -20px 0 -40px -40px;\n\t\twidth: calc(100% + 80px);\n\t\tbackground: #1D3F88;\n\t...
# 12  Требуемый опыт работы: 1–3 годаПолная занятость, полный деньТребуемый опыт работы: 1–3 года Полная занятость, полный день Обязанности: - Подготовка удобных для использования онлайн событий для систем принятия решений - Оптимизация процессов по генерации событий Требования: - Хорошее владение Python 3.6+ - Опыт работы с библиотеками: datetime, os, configparser, cx_Oracle, confluent_kafka, pickle, hashlib, json, logging, ntpath, time, kafka, sys, dateutil, pymssql, psycopg2, pymysql, lxml, htt...
# 13  Требуемый опыт работы: 1–3 годаПолная занятость, полный деньKolesa Group - международная, продуктовая IT-компания со стержнем. Задаем новые тенденции в мире высоких технологий, делая продукты для 12 миллионов пользователей в Казахстане и Узбекистане.Каждый из нас - фанат своего дела, а вместе мы ежедневно вносим вклад в развитие наших продуктов. Поддерживаем открытость, инициативность и постоянное желание развиваться.Сегодня в команду мы ищем Data-инженера. Вам предстоит:   Работа с аналитик...
# 14  Требуемый опыт работы: 1–3 годаПолная занятость, полный деньKolesa Group - международная, продуктовая IT-компания со стержнем. Задаем новые тенденции в мире высоких технологий, делая продукты для 12 миллионов пользователей в Казахстане и Узбекистане.Каждый из нас - фанат своего дела, а вместе мы ежедневно вносим вклад в развитие наших продуктов. Поддерживаем открытость, инициативность и постоянное желание развиваться.Сегодня мы в поисках опытного MLOps Backend-разработчика, который будет раз...
# 15  Требуемый опыт работы: 1–3 годаПолная занятость, полный деньОбязанности:  Бизнес аналитика при внедрении проектов; Поиск, анализ и внедрение инструментов противодействия мошенничеству в розничном кредитовании; Работа с данными; Оценка влияния предлагаемых мер снижения рисков на кредитный портфель; Разработка бизнес требований.  Требования:  Высшее образование в области математики, IT сфера, финансы; Желателен опыт работы в банковской сфере не менее 2-х лет; Знание SQL, Python, продуктов SAS....
# 16  Требуемый опыт работы: 1–3 годаПолная занятость, полный деньОбязанности:  выполнение ручных (manual) и автоматических (automated) тестов; анализ, регистрация и описание полученных результатов; коммуникация с заинтересованными лицами (внутренняя/внешняя); предоставление отчетности; работа с требованиями, спецификациями (обсуждение, инспекции и т.д.); разработка дизайна тестов, ручных (manual) и автоматических (automated) тестов на основе дизайна; обеспечение необходимой полноты разработки тес...
# 17  Требуемый опыт работы: более 6 летПолная занятость, полный деньКомпания Mycar Group, проект Mycar Pro находится в поиске Tech Lead. Mycar Pro - система автоматизации бизнеса для дилерских центров, предполагает постоянную связь экосистемы с клиентом: это, в том числе, ведение клиентской базы, воронка продаж, таргетированные напоминания, различные инструменты для ценообразования (калькулятор/конструктор), сохранение всей вводной информации (база данных всех проведённых активностей по оценке) и...
# 18  Требуемый опыт работы: 3–6 летПолная занятость, полный деньRelog - международная IT - компания. Создаем инновационные продукты в сфере логистики. Используем современные технологии в разработке. Relog используют 200+ компаний из СНГ и это не предел.Нас объединяет интерес к сложным задачам, жажда новых знаний и командная работа. Сейчас мы в поиске Senior Backend-разработчика.  Наш стэк:   NodeJS,JavaScript,Meteor, Go;   MongoDB, ClickHouse;   Gitlab;   Kubernates, Docker.   Что нужно знать и у...
# 19  Требуемый опыт работы: 1–3 годаЧастичная занятость, гибкий графикВозможно временное оформление: договор услуг, подряда, ГПХ, самозанятые, ИПВозможна подработка: сменами по 4-6 часов или по вечерамОбязанности:  Подготовка методического материала по выбранному языку программирования Обучение программированию Контроль успеваемости и выполнения заданий Предоставление обратной связи ученикам  Требования:  Знание теории Алгоритмов и структуры данных Знание синтаксиса языка программирования Знание ...
#
#                                      Employer
# 0                         ТОО Click Logistics
# 1                          ТОО LEOPART CENTER
# 2                         ТОО GLOBAL Innotion
# 3                                 Chocofamily
# 4                         ЧК ITS PARTNER LTD.
# 5                               АО Jusan Bank
# 6                                     Soshace
# 7                               Петухова Алия
# 8                                    inDriver
# 9                            ТОО Prime Source
# 10                                     KIVORK
# 11                       Евразийский банк, АО
# 12                             Kaspi Bank, АО
# 13                               Kolesa Group
# 14                               Kolesa Group
# 15                        АО Банк ЦентрКредит
# 16  ТОО Suretter Software (Суреттер Софтваре)
# 17                            ТОО MyCar Group
# 18                               ТОО Relog.kz
# 19                           ТОО 2дэй академи

# %%
df.to_csv('Task1.csv', index=False, encoding='utf-8')
